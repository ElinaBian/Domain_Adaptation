# %%
from data_process.usps_data import *
from data_process.mnist_data import *
from data_process.visualization import *
import matplotlib.pyplot as plt
import glob
from mcd_usps2mnist_Mom import *

# %%
usps_images_train, usps_labels_train = load_usps_train_data()
usps_images_test, usps_labels_test = load_usps_test_data()

print("USPS_train_images shape: {}, USPS_train_labels shape: {}".format(usps_images_train.shape, usps_labels_train.shape))
print("USPS_test_images shape: {}, USPS_test_labels shape: {}".format(usps_images_test.shape, usps_labels_test.shape))
# Out:
# 2000 images in class0
# 2000 images in class1
# 1999 images in class2
# 2000 images in class3
# 2000 images in class4
# 2000 images in class5
# 2000 images in class6
# 2000 images in class7
# 2000 images in class8
# 2000 images in class9
# 150 images in class0
# 150 images in class1
# 150 images in class2
# 150 images in class3
# 150 images in class4
# 150 images in class5
# 150 images in class6
# 150 images in class7
# 150 images in class8
# 150 images in class9
# USPS_train_images shape: (19999, 28, 28), USPS_train_labels shape: (19999, 10)
# USPS_test_images shape: (1500, 28, 28), USPS_test_labels shape: (1500, 10)

# %%
ind_tr = np.random.choice(19999, 1800, replace = False)
ind_ts = np.random.choice(1500, 1200, replace = False)

usps_tr_im = np.reshape(usps_images_train, (-1, 784))
usps_tr_im = usps_tr_im[ind_tr,:]
usps_ts_im = np.reshape(usps_images_test, (-1, 784))
usps_ts_im = usps_ts_im[ind_ts,:]
usps_tr_labels = usps_labels_train
usps_tr_labels = usps_tr_labels[ind_tr,:]
usps_ts_labels = usps_labels_test
usps_ts_labels = usps_ts_labels[ind_ts,:]

ind_tr = np.random.choice(55000, 2000, replace = False)
ind_ts = np.random.choice(10000, 1500, replace = False)

mnist_images_train, mnist_labels_train, mnist_images_test, mnist_labels_test = load_mnist_data(28)
mnist_tr_im = mnist_images_train
mnist_tr_im = np.reshape(mnist_tr_im, (-1, 784))
mnist_tr_im = mnist_tr_im[ind_tr,:]
mnist_ts_im = mnist_images_test
mnist_ts_im = np.reshape(mnist_ts_im, (-1, 784))
mnist_ts_im = mnist_ts_im[ind_ts,:]
mnist_tr_labels = mnist_labels_train
mnist_tr_labels = mnist_tr_labels[ind_tr,:]
mnist_ts_labels = mnist_labels_test
mnist_ts_labels = mnist_ts_labels[ind_ts,:]
# Out:
# WARNING:tensorflow:From /home/ecbm4040/uda_try/data_process/mnist_data.py:21: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/ecbm4040/miniconda3/envs/dlenv/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/ecbm4040/miniconda3/envs/dlenv/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
filter_size = 5
n_filters_1 = 32
n_filters_2 = 48

n_units_g = 768   # 768 = 4*4*48
n_units_gc = 100
n_units_c = 100

learning_rate = 0.0002
epoch = 200
num_stepC = 3
batch_size = 32
show_step = 500
model_path = '/model'
is_saving = False

# %%
mcd = MCD_DA()
mcd.train(images_train_1=usps_tr_im, labels_train_1=usps_tr_labels, images_test_1=usps_ts_im, \
          labels_test_1=usps_ts_labels, images_train_t=mnist_tr_im, labels_train_t=mnist_tr_labels,\
          images_test_t=mnist_ts_im, labels_test_t=mnist_ts_labels, \
          filter_size=filter_size, n_filters_1=n_filters_1, n_filters_2=n_filters_2, \
          n_units_g=n_units_g, n_units_c = n_units_c, n_units_gc = n_units_gc,\
          learning_rate = learning_rate, epoch = epoch, num_stepC = num_stepC, batch_size = batch_size, show_step = show_step, \
          is_saving = is_saving, model_path = model_path)
# Out:
# WARNING:tensorflow:From /home/ecbm4040/uda_try/mcd_usps2mnist_Mom.py:230: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# number of batches for training: 62
# epoch 1
# ---------------
# Iteration: 0, Loss_test_a: 5.129301847950105, Loss_test_b: 5.035625896146221, Loss_test_c: 0.09335199887714078
# Source test acc1: 15.625%, Source test acc2: 11.441532258064516%.
# Best test accuracy classifier1! Iteration:0 accuracy: 11.895161290322582%
# Best test accuracy classifier2! Iteration:0 accuracy: 8.46774193548387%
# epoch 2
# ---------------
# Iteration: 62, Loss_test_a: 2.0991969954582954, Loss_test_b: 2.0546200775331065, Loss_test_c: 0.0487665711271186
# ...
